# %%
import pandas as pd
import numpy as np
import nltk

# %%
import os
os.getcwd()
# Out:
# '/Users/umarranginwala/Documents/untitled folder/Folder/NLP/Practicals'

# %%
data = pd.read_csv("preprocessing data.csv")

# %%
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
data.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
data["tweet_lower"] = data["tweet"].str.lower()

# %%
## Removing Puntuations

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
puntuations_to_remove = string.punctuation
